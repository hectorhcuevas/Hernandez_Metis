# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn import preprocessing


# %matplotlib inline

# %%
#df = pd.read_csv('/Users/hector/Downloads/national-health-and-nutrition-examination-survey/questionnaire.csv')

# %%
#df['DIQ010'].head(20)

# %%
#df1 = df[['PAQ678','DIQ010']]

# %%
#df1.head()

# %%
#dfSTR = df1.dropna(axis=0,how='any')

# %%
#dfSTR

# %%
#dfSTR.head()

# %%
#dfSTR['DIQ010_1.0'].max()

# %%
#dfSTR['Diabetic'] = dfSTR['DIQ010']

# %%
#dfSTR['DiabRisk'] = dfSTR['DIQ010'].replace({1.0: 1.0, 2.0: 0.0, 3.0: 1.0}, inplace=True)

# %%
#dfSTR['DIQ010'].sort_values(ascending=False)

# %%
#df1['DIQ010'].sort_values(ascending=False)

# %%
#dfSTR.PAQ678.value_counts()[[1,2,3,4,5,6,7]]

# %%
df_ = pd.read_csv('/Users/hector/Downloads/behavioral-risk-factor-surveillance-system/2015.csv')
df_

# %%
df_['STR'] = df_['STRENGTH'].dropna(axis=0,how='any')

# %%
''''''''''
STR = []
for row in df_['STRENGTH']:
    if 100 < row < 200:
        STR.append(row-100)
    elif 200 < row < 300:
        STR.append((row-200)/4)
df_['STR_'] = STR
'''''''''''

# %%
#Creating a new column for Strength Training Frequency

STR = []
for row in df_['STR']:
    if 100 < row < 107: ## If responded in 100's, this is a weekly frequency hence we subtract 100
        STR.append(row-100)
    elif 107 < row < 199: # If responded > 100, we assume they strength train daily and replace value as 7 
        STR.append(7)
    elif 200 < row <= 228: ## answers in 200s were monthly, so we want to subtract 200 and divide by 4(weeks in a month)
        STR.append((row-200)/4) ## This gives us weekly values
    elif 228 < row < 300:
        STR.append(7)
    elif row > 300:
        STR.append(0) ## if responded 777 or 888, replace as 0 because they never str train or refused to respond 
df_['STR_'] = pd.Series(STR)

# %%
df_['STR_'].mean()

# %%
df_

# %%
df_2 = df_
df_2['STR_'] = df_['STR_'].dropna(axis=0,how='any')

# %%
df_2['STR_'].dropna(axis=0,how='any',inplace=True)

# %%
sns.lmplot(x="STR_", y="_BMI5CAT", data=df_2);

# %%
df_2['STR_'].max()

# %%
df_2['STR_'].mean()

# %%
df_2['STR_'].mean()
# Out:
# 1.0002017040159525

# %%
df_2 = df_2[pd.notnull(df_2['STR_'])]

# %%
df_2
# Out:
#         _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0          1.0     1.0  b'01292015'  b'01'  b'29'  b'2015'    1200.0
# 1          1.0     1.0  b'01202015'  b'01'  b'20'  b'2015'    1100.0
# 2          1.0     1.0  b'02012015'  b'02'  b'01'  b'2015'    1200.0
# 3          1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0
# 4          1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0
# 5          1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0
# 6          1.0     1.0  b'01052015'  b'01'  b'05'  b'2015'    1100.0
# 7          1.0     1.0  b'01142015'  b'01'  b'14'  b'2015'    1100.0
# 8          1.0     1.0  b'01132015'  b'01'  b'13'  b'2015'    1100.0
# 9          1.0     1.0  b'01302015'  b'01'  b'30'  b'2015'    1100.0
# 10         1.0     1.0  b'01222015'  b'01'  b'22'  b'2015'    1100.0
# 11         1.0     1.0  b'01162015'  b'01'  b'16'  b'2015'    1100.0
# 12         1.0     1.0  b'01202015'  b'01'  b'20'  b'2015'    1200.0
# ...
