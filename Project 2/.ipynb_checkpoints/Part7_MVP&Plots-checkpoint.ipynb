# %%
from __future__ import print_function, division
import plotly.plotly as py

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# all of the imports
import pandas as pd
import numpy as np
import pickle 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import RidgeCV
import pickle
import seaborn as sns
import scipy.stats as stats



# %matplotlib inline

# %%
## Loading dataset and creating multiple plots for MVP presentation

df = pd.read_csv('./data/Model_Data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Percent_Obese', 'GDPper_cap',
#        'Insufficiently_active', 'Education', 'Region_Africa',
#        'Region_Arab_States', 'Region_Europe', 'Region_Asia', 'Region_Oceania',
#        'Region_Latin_America', 'Region_CIS', 'Globalization_index',
#        'Urbanization_Rate', 'Urban_Population', 'Imports', 'log(Imports)',
#        'log(Imports)*Asia', 'Asia*Urbanization', 'UrbanPop*ArabStates',
#        'Asia*Globalization', 'Urbanization*GDPpercap', 'Europe*GDPpercap'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Education')
ax.set_ylabel('Percent Obese')
m, b = np.polyfit(df.Education, df.Percent_Obese, 1)
plt.plot(df.Education, df.Percent_Obese, '.')
plt.plot(df.Education, m*df.Education + b, '-');

# %%
fig, ax = plt.subplots()
sns.set_style("darkgrid")
ax.set_xlabel('GDPper_cap')
ax.set_ylabel('Percent Obese')
m, b = np.polyfit(df.GDPper_cap, df.Percent_Obese, 1)
plt.plot(df.GDPper_cap, df.Percent_Obese, '.')
plt.plot(df.GDPper_cap, m*df.GDPper_cap + b, '-');
fig.savefig('GDP Per Cap.png', bbox_inches='tight')

# %%
fig2 = pylab.figure()
sns.regplot(x=df["log(GDPper_cap)"], y=df["Percent_Obese"], line_kws={"color":"r","alpha":0.7,"lw":5})
#sns.plt.show()

# %%
fig2.savefig('./images/log(GDP).png')

# %%
df.Insufficiently_active.hist();

# %%
import pylab
fig3 = pylab.figure()
sns.regplot(x=df["Insufficiently_active"], y=df["Percent_Obese"], line_kws={"color":"r","alpha":0.7,"lw":5})
sns.plt.show();

# %%
fig3.savefig('./images/inactivity.png')

# %%
stats.probplot(df['Urbanization_Rate'], dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
# plot Education 
fig1 = pylab.figure()

sns.regplot(x=df["Education"], y=df["Percent_Obese"], line_kws={"color":"r","alpha":0.7,"lw":5})
sns.plt.show();

# %%
fig1.savefig('./images/Education.png')

# %%
df2 = df[['Percent_Obese', 'log(GDPper_cap)',
       'Insufficiently_active', 'Education']]

# %%
sns.pairplot(df2, kind="reg")
plt.show()

# %%
df = pd.read_csv('./data/Model_Data.csv')

# %%
fig_1 = sns.jointplot("Education", "Percent_Obese", data=df, kind="reg")

# %%
fig_2 = sns.jointplot("log(GDPper_cap)", "Percent_Obese", data=df, kind="reg")

# %%
fig_3 = sns.jointplot("Insufficiently_active", "Percent_Obese", data=df, kind="reg")

# %%
fig_1.savefig('./images/Education.png')
fig_2.savefig('./images/log(GDP).png')
fig_3.savefig('./images/inactivity.png')

# %%
fig_ = pylab.figure()
fig, axs = plt.subplots(ncols=3,figsize=(12,5))
sns.regplot(x='Education', y='Percent_Obese', data=df, ax=axs[0])
sns.regplot(x='log(GDPper_cap)', y='Percent_Obese', data=df, ax=axs[1])
sns.regplot(x='Insufficiently_active',y='Percent_Obese', data=df, ax=axs[2])
axs[0].set(xlabel='Education', ylabel='Obesity (% of Population)')
axs[1].set(xlabel='log(GDP Per Capita)', ylabel='')
axs[2].set(xlabel='Insufficiently Active (%)', ylabel='');

# %%
fig.savefig('./images/Subplots.png')

# %%
import seaborn as snssns.set(style="darkgrid")
>>> titanic = sns.load_dataset("titanic")
>>> ax = sns.countplot(x="class", data=titanic)

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-253bcac7dd80> in <module>()
# ----> 1 X
#
# NameError: name 'X' is not defined
