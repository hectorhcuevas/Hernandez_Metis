# %%
from __future__ import print_function, division

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# all of the imports
import pandas as pd
import numpy as np
import pickle 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import RidgeCV
import pickle
import seaborn as sns
import scipy.stats as stats



# %matplotlib inline

# %%
df = pd.read_csv('Obese_Model_data.csv')

# %%
df.sort_values('GDPper_cap', ascending=False)
# Out:
#      Unnamed: 0                   country  Percent_Obese  GDPper_cap  \
# 1             1                     Qatar           42.3      127700
# 3             3                 Singapore            6.2       87900
# 4             4                    Kuwait           39.7       71900
# 5             5                   Ireland           25.6       69200
# 6             6                    Norway           23.1       69200
# 7             7      United Arab Emirates           37.2       67900
# 8             8               Switzerland           19.4       59600
# 9             9              Saudi Arabia           34.7       55200
# 10           10               Netherlands           19.8       51000
# 11           11                   Bahrain           35.1       50700
# 12           12                    Sweden           20.5       49800
# 13           13                   Iceland           22.8       49200
# 14           14                 Australia           28.6       48900
# ...

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Education')
ax.set_ylabel('Percent Obese')
m, b = np.polyfit(df.Education, df.Percent_Obese, 1)
plt.plot(df.Education, df.Percent_Obese, '.')
plt.plot(df.Education, m*df.Education + b, '-');

# %%
fig, ax = plt.subplots()
sns.set_style("darkgrid")
ax.set_xlabel('GDPper_cap')
ax.set_ylabel('Percent Obese')
m, b = np.polyfit(df.GDPper_cap, df.Percent_Obese, 1)
plt.plot(df.GDPper_cap, df.Percent_Obese, '.')
plt.plot(df.GDPper_cap, m*df.GDPper_cap + b, '-');
fig.savefig('GDP Per Cap.png', bbox_inches='tight')

# %%
sns.regplot(x=df["Urban_Population"], y=df["Percent_Obese"], line_kws={"color":"r","alpha":0.7,"lw":5})
#sns.plt.show()

# %%
df.Insufficiently_active.hist();

# %%
import pylab
fig = pylab.figure()
sns.regplot(x=df["UrbanPop*ArabStates"], y=df["Percent_Obese"], line_kws={"color":"r","alpha":0.7,"lw":5})
sns.plt.show();

# %%
fig.savefig('GDP.png')

# %%
stats.probplot(df['Urbanization_Rate'], dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x=df.Education, y=df.Percent_Obese, data=df, fit_reg=False, hue='Region', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
